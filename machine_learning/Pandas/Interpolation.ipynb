# %% [markdown]
# <a href="https://colab.research.google.com/github/student-sayan/C_plus_plus_Programs/blob/main/machine_learning/Pandas/Interpolation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Hello

# %%
import pandas as pd
